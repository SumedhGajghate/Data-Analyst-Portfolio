# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\PROJECTS\Data analaytics\Python data analytics\Untitled.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PROJECTS/Data%20analaytics/Python%20data%20analytics/Untitled.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\PROJECTS\Data analaytics\Python data analytics\Untitled.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PROJECTS/Data%20analaytics/Python%20data%20analytics/Untitled.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/d%3A/PROJECTS/Data%20analaytics/Python%20data%20analytics/Untitled.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/d%3A/PROJECTS/Data%20analaytics/Python%20data%20analytics/Untitled.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> import numpy as np
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
detaset= pd.read_csv("Superstor_USA.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\PROJECTS\Data analaytics\Python data analytics\Untitled.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PROJECTS/Data%20analaytics/Python%20data%20analytics/Untitled.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> detaset= pd.read_csv("Superstor_USA.csv")
#
# NameError: name 'pd' is not defined

# %%
detaset.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\PROJECTS\Data analaytics\Python data analytics\Untitled.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PROJECTS/Data%20analaytics/Python%20data%20analytics/Untitled.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> detaset.head(2)
#
# NameError: name 'detaset' is not defined

# %%
# !pip install pandas

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\PROJECTS\Data analaytics\Python data analytics\Untitled.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PROJECTS/Data%20analaytics/Python%20data%20analytics/Untitled.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.0 kB ? eta -:--:--
#      -------------------------------------- 61.0/61.0 kB 819.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 1.2 MB/s eta 0:00:10
#     --------------------------------------- 0.2/11.5 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.3/11.5 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.4/11.5 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/11.5 MB 1.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/11.5 MB 1.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/11.5 MB 1.5 MB/s eta 0:00:08
# ...

# %%
import pandas

# %%
import matplotlib.pyplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\PROJECTS\Data analaytics\Python data analytics\Untitled.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PROJECTS/Data%20analaytics/Python%20data%20analytics/Untitled.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      ------- ------------------------------- 30.7/165.5 kB 1.3 MB/s eta 0:00:01
#      ------- ------------------------------- 30.7/165.5 kB 1.3 MB/s eta 0:00:01
#      ---------------------------- --------- 122.9/165.5 kB 1.2 MB/s eta 0:00:01
#      ------------------------------------ 165.5/165.5 kB 995.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#     --------------------------------------- 0.1/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.4/8.0 MB 5.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.5/8.0 MB 4.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/8.0 MB 6.3 MB/s eta 0:00:02
#    -------- ------------------------------- 1.7/8.0 MB 7.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.3/8.0 MB 8.6 MB/s eta 0:00:01
# ...

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    --------- ----------------------------- 71.7/294.9 kB 787.7 kB/s eta 0:00:01
#    --------------------------- ------------ 204.8/294.9 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
detaset= pd.read_excel("Superstor_USA.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\PROJECTS\Data analaytics\Python data analytics\Untitled.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PROJECTS/Data%20analaytics/Python%20data%20analytics/Untitled.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> detaset= pd.read_excel("Superstor_USA.xlsx")
#
# NameError: name 'pd' is not defined

# %%
detaset= pd.read_csv("Superstore_USA.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\PROJECTS\Data analaytics\Python data analytics\Untitled.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PROJECTS/Data%20analaytics/Python%20data%20analytics/Untitled.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> detaset= pd.read_csv("Superstore_USA.csv")
#
# NameError: name 'pd' is not defined

# %%
detaset= pd.read_csv("Superstore_USA.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# d:\PROJECTS\Data analaytics\Python data analytics\Untitled.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PROJECTS/Data%20analaytics/Python%20data%20analytics/Untitled.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> detaset= pd.read_csv("Superstore_USA.csv")
#
# ...

# %%
detaset= pd.read_excel("Superstore_USA.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\PROJECTS\Data analaytics\Python data analytics\Untitled.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PROJECTS/Data%20analaytics/Python%20data%20analytics/Untitled.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> detaset= pd.read_excel("Superstore_USA.xlsx")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
detaset= pd.read_excel("Superstore_USA.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\$umedh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\$umedh\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
detaset= pd.read_csv("Superstore_USA.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# d:\PROJECTS\Data analaytics\Python data analytics\Untitled.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PROJECTS/Data%20analaytics/Python%20data%20analytics/Untitled.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> detaset= pd.read_csv("Superstore_USA.csv")
#
# ...

# %%
 dataset = pd.read_csv("Superstore_USA.csv", encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dataset = pd.read_csv("Superstore_USA.csv", encoding='utf-8')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
 dataset = pd.read_csv("Superstore_USA.csv", encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File parsers.pyx:1120, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File parsers.pyx:1272, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File parsers.pyx:1285, in pandas._libs.parsers.TextReader._string_convert()
#
# File parsers.pyx:1535, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x99 in position 21: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dataset = pd.read_csv("Superstore_USA.csv", encoding='utf-8')
#
# ...

# %%
 dataset = pd.read_csv("Superstore_USA.csv", encoding='latin1')

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
 dataset = pd.read_csv("Superstore_USA.csv", encoding='latin1')

# %% [markdown]
# #Order Priority

# %%
dataset.head (2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code  Order Date   Ship Date  \
# 0  Central          Illinois    Addison        60101  28-05-2012  30-05-2012
# 1     West        Washington  Anacortes        98221  07-07-2010  08-07-2010
#
#   Profit  Quantity ordered new  Sales Order ID
# 0   1.32                     2   5.90    88525
# 1   4.56                     4  13.01    88522
#
# [2 rows x 24 columns]

# %%
dataset.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
dataset['Product Base Margin'].fillna(dataset['Product Base Margin'].mean(), inplace= True)
# Out:
# C:\Users\$umedh\AppData\Local\Temp\ipykernel_5036\1877902152.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Product Base Margin'].fillna(dataset['Product Base Margin'].mean(), inplace= True)

# %%
dataset.shape
# Out:
# (9426, 24)

# %%
dataset['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: count, dtype: int64

# %%
dataset['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
dataset['Order Priority'] = dataset['Order Priority'].replace("Critical", "Critical ")

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Order Priority", data=dataset)
plt.title("Count of order priority")
plt.savefig("count of order priority")
plt.show()

# %% [markdown]
# #Ship Mode

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
x=dataset['Ship Mode'].value_counts().index
y=dataset['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(5,4))
plt.pie(y,labels=x,autopct="%0.2f%%",startangle=60)
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Ship Mode", data=dataset, hue="Product Category")
plt.show()

# %% [markdown]
# #Coustomer Segment

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Customer Segment", data=dataset)
plt.show()

# %% [markdown]
# #Product Category

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Product Category", data=dataset)
plt.show()

# %% [markdown]
# #Product Sub-Category (Office Supplies)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Product Category", data=dataset[dataset['Product Category']=="Office Supplies"],hue="Product Sub-Category")
plt.show()

# %% [markdown]
# #Product Sub-Category (Technology Product)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Product Category", data=dataset[dataset['Product Category']=="Technology"],hue="Product Sub-Category")
plt.show()

# %%
dataset["Product Category"].unique()
# Out:
# array(['Office Supplies', 'Technology', 'Furniture'], dtype=object)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Product Category", data=dataset[dataset['Product Category']=="Furniture"],hue="Product Sub-Category")
plt.show()

# %%
dataset['Order Date'] = pd.to_datetime(dataset['Order Date'], errors='coerce')
# Out:
# C:\Users\$umedh\AppData\Local\Temp\ipykernel_5036\2607478334.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   dataset['Order Date'] = pd.to_datetime(dataset['Order Date'], errors='coerce')

# %%
dataset["Order Year"] = dataset['Order Date'].dt.year

# %%
dataset['Order Year'].value_counts()
# Out:
# Order Year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %%
order_counts_per_year = dataset['Order Year'].value_counts().sort_index()

# %%
plt.figure(figsize=(5,4))
plt.plot(order_counts_per_year.index, order_counts_per_year.values,marker='o')
plt.show()

# %%
sns.barplot(x='Product Category',y='Profit', data=dataset,estimator='sum')
plt.show()
